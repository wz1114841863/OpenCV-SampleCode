# %%
#函数：cv.HoughCircles()
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('../Images/img16_1.jpg')
#img = img[:, :, :: -1]
#img_med = cv.medianBlur(img,5)
#plt.imshow(img_med)
#plt.show()
img_gray = cv.cvtColor(img_med, cv.COLOR_BGR2GRAY)
#plt.imshow(img_gray, 'gray')
#plt.show()
circles = cv.HoughCircles(img_gray,cv.HOUGH_GRADIENT,1,20,
                          param1=50,param2=30,minRadius=0,maxRadius=0)
circles = np.uint16(np.around(circles))
print(circles.shape)

for i in circles[0,:]:
    # 绘制外圆
    cv.circle(img,(i[0],i[1]),i[2],(0,255,0),2)
    # 绘制圆心
    cv.circle(img,(i[0],i[1]),2,(255,0,255),3)
    
"""
cv.imshow('detected circles',img)
cv.waitKey(0)
cv.destroyAllWindows()
"""
img = img[:, :, :: -1]
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (1, 4, 3)
# (300, 400, 3)
