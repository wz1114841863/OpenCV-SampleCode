# %%
#函数: cv.HoughLines(), cv.HoughLinesP()
import cv2 as cv 
import numpy as np
from matplotlib import pyplot as plt 
#OpenCV中的霍夫变换

img9 = cv.imread("../Images/img9.png")
#print(img9.shape)
gray = cv.cvtColor(img9, cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray, 50, 150, apertureSize = 3)
lines = cv.HoughLines(edges, 1, np.pi / 180, 200)
for line in lines:
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    cv.line(img9,(x1,y1),(x2,y2),(0,0,255),2)

img9 = img9[:, :, ::-1]
plt.imshow(img9)
plt.show()

# %%
#概率霍夫变换
#需要重新加载图片，之前的图片已经画了线 
img9 = cv.imread("../Images/img9.png")
#print(img9.shape)
gray = cv.cvtColor(img9, cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray, 50, 150, apertureSize = 3)
lines = cv.HoughLines(edges, 1, np.pi / 180, 200)
lines = cv.HoughLinesP(edges,1,np.pi/180,100,minLineLength=100,maxLineGap=10)
for line in lines:
    x1,y1,x2,y2 = line[0]
    cv.line(img9,(x1,y1),(x2,y2),(0,255,0),2)
plt.imshow(img9)
plt.show()
